# %%
# %cd /kaggle/working
# !git clone --depth=1 https://github.com/ggerganov/llama.cpp.git
# %cd /kaggle/working/llama.cpp
# !sed -i 's|MK_LDFLAGS   += -lcuda|MK_LDFLAGS   += -L/usr/local/nvidia/lib64 -lcuda|' Makefile
# !LLAMA_CUDA=1 conda run -n base make -j > /dev/null
# Out:
# /kaggle/working
# fatal: destination path 'llama.cpp' already exists and is not an empty directory.
# /kaggle/working/llama.cpp

# %% [markdown]
# The quantize script requires a GGUF model directory, output file directory, and quantization method. We are converting the model using the Q4_K_M method.

# %%
# %cd /kaggle/working/

# !./llama.cpp/llama-quantize /kaggle/input/model-to-llama-cpp-ggu-part3/llama-3-8b-chat-doctor.gguf llama-3-8b-chat-doctor-Q4_K_M.gguf Q4_K_M
# Out:
# /kaggle/working
# main: build = 1 (4b77ea9)
# main: built with cc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0 for x86_64-linux-gnu
# main: quantizing '/kaggle/input/model-to-llama-cpp-ggu-part3/llama-3-8b-chat-doctor.gguf' to 'llama-3-8b-chat-doctor-Q4_K_M.gguf' as Q4_K_M
# llama_model_loader: loaded meta data with 27 key-value pairs and 291 tensors from /kaggle/input/model-to-llama-cpp-ggu-part3/llama-3-8b-chat-doctor.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Llama 3 8b Chat Doctor
# llama_model_loader: - kv   3:                           general.finetune str              = chat-doctor
# ...

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient
from huggingface_hub import HfApi
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("huggi_fac")
login(token = hf_token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
api = HfApi()
api.upload_file(
    path_or_fileobj="/kaggle/working/llama-3-8b-chat-doctor-Q4_K_M.gguf",
    path_in_repo="llama-3-8b-chat-doctr-Q4_K_M.gguf",
    #repo_id="kingabzpro/llama-3-8b-chat-doctor",
    repo_id="Deepakiitm/llama-3-8b-chat-doctor",
    repo_type="model",
)
# Out:
# llama-3-8b-chat-doctor-Q4_K_M.gguf:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Deepakiitm/llama-3-8b-chat-doctor/commit/790386c23808eed690d1ffcab380c3da3979afe3', commit_message='Upload llama-3-8b-chat-doctr-Q4_K_M.gguf with huggingface_hub', commit_description='', oid='790386c23808eed690d1ffcab380c3da3979afe3', pr_url=None, pr_revision=None, pr_num=None)

# %%
# !ls /kaggle/working
# Out:
# llama-3-8b-chat-doctor-Q4_K_M.gguf  llama.cpp
